# %% [markdown]
# Started with looking

# %% [markdown]
# # Questions to ASK
#  - Ratio of Revenue to your salary?
#  - How many ask for X number of expierences?
#  - How many ask for X amount of degrees?
#  - Somehow show min/max as an aggregated spread of the ranges
#  - How easily can one make a cvec's Job Description/Title model for predicting average offered Salary
#  - Correlations from specific words to amounts?

# %% [markdown]
# ## 1. Imports

# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('./Job_data/data_cleaned_9_13_20.csv')

# %%
df.to_excel('./Job_data/data_cleaned_9_14_20.xlsx')

# %%
df_one = pd.read_csv('./Job_data/DataAnalyst.csv')
print(df_one.shape)
df_one.head(3)
# Out:
# (2253, 16)
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
# 2                         Squarespace\n3.4  New York, NY  New York, NY
#
#                      Size  Founded       Type of ownership  \
# 0    201 to 500 employees     1961  Nonprofit Organization
# 1        10000+ employees     1893  Nonprofit Organization
# 2  1001 to 5000 employees     2003       Company - Private
#
#                            Industry                  Sector  \
# 0                 Social Assistance              Non-Profit
# 1  Health Care Services & Hospitals             Health Care
# 2                          Internet  Information Technology
#
#                       Revenue Competitors Easy Apply
# 0  $100 to $500 million (USD)          -1       True
# 1      $2 to $5 billion (USD)          -1         -1
# 2    Unknown / Non-Applicable     GoDaddy         -1

# %%
df_two = pd.read_csv('./Job_data/DataScientist.csv')
print(df_two.shape)
df_two.head(3)
# Out:
# (3909, 17)
#    Unnamed: 0  index                          Job Title  \
# 0           0      0              Senior Data Scientist
# 1           1      1  Data Scientist, Product Analytics
# 2           2      2               Data Science Manager
#
#                 Salary Estimate  \
# 0  $111K-$181K (Glassdoor est.)
# 1  $111K-$181K (Glassdoor est.)
# 2  $111K-$181K (Glassdoor est.)
#
#                                      Job Description  Rating  Company Name  \
# 0  ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...     3.5   Hopper\n3.5
# 1  At Noom, we use scientifically proven methods ...     4.5  Noom US\n4.5
# 2  Decode_M\n\nhttps://www.decode-m.com/\n\nData ...    -1.0      Decode_M
#
#        Location      Headquarters                    Size  Founded  \
# 0  New York, NY  Montreal, Canada   501 to 1000 employees     2007
# 1  New York, NY      New York, NY  1001 to 5000 employees     2008
# 2  New York, NY      New York, NY       1 to 50 employees       -1
#
#    Type of ownership                   Industry             Sector  \
# 0  Company - Private            Travel Agencies   Travel & Tourism
# 1  Company - Private  Health, Beauty, & Fitness  Consumer Services
# 2            Unknown                         -1                 -1
#
#                     Revenue Competitors Easy Apply
# 0  Unknown / Non-Applicable          -1         -1
# 1  Unknown / Non-Applicable          -1         -1
# 2  Unknown / Non-Applicable          -1       True

# %% [markdown]
# There were three other datasets that I found, but they were dirtier and I figured these two sets were plenty enough without needing to burn a bunch of time on cleaning.

# %% [markdown]
# ## Dropping & Concatting

# %%
df_one.drop('Unnamed: 0', axis = 1, inplace = True)

df_two.drop(['Unnamed: 0','index'], axis = 1, inplace = True)

list_dfs = [df_one, df_two]
df = pd.concat(list_dfs)

df.reset_index(inplace = True)

# %% [markdown]
# ## Filling Na's (listed in data as -1)

# %%
df['Easy Apply'].value_counts()
# Out:
# -1      5918
# True     244
# Name: Easy Apply, dtype: int64

# %%
df['Easy Apply'].replace('-1', False, inplace = True)

df['Easy Apply'].value_counts()

# %%
# This will both replace the Na's as well as 
def funt_min(x, regex = r'\$\d+K', front = '$'):
    cell = re.search(regex, x)
    if type(cell)== type(None):
        cell = -1
    else:
        cell = cell.group()
        cell = cell.strip('K').strip(front)
        cell = int(cell)# * 1000
    return cell

df['Salary_min_grand'] = df['Salary Estimate'].map(lambda x: funt_min(x))

df['Salary_max_grand'] = df['Salary Estimate'].map(lambda x: funt_min(x, 
                                                   regex = r'-\$\d+K', front = '-$'))

# %%
df['Revenue'].value_counts()
# Out:
# Unknown / Non-Applicable            1778
# $10+ billion (USD)                   788
# $100 to $500 million (USD)           556
# $50 to $100 million (USD)            413
# -1                                   392
# $2 to $5 billion (USD)               340
# $10 to $25 million (USD)             323
# $1 to $5 million (USD)               281
# $1 to $2 billion (USD)               267
# $25 to $50 million (USD)             253
# Less than $1 million (USD)           217
# $500 million to $1 billion (USD)     193
# $5 to $10 billion (USD)              189
# $5 to $10 million (USD)              172
# Name: Revenue, dtype: int64

# %%
df['Revenue'].replace('-1', 'Unknown / Non-Applicable', inplace = True)

# %% [markdown]
# I've got some -1's in the Salary ranges, lets look into that.

# %%
mask = df['Salary_min_grand'] == -1
df[mask].head(10)
# Out:
#       index                                          Job Title  \
# 2149   2149          Configuration/Data Management Analyst III
# 2938    685            Clinical Laboratory Scientist, Per Diem
# 2939    686                                   Sr. Data Analyst
# 2940    687       Lead Data Science Instructor, Data Scientist
# 2941    688  Clinical Laboratory Scientist (Per Diem, Varia...
# 2942    689                                      Data Engineer
# 2943    690         Clinical Laboratory Scientist - Generalist
# 2944    691           Clinical Laboratory Scientist , Med Tech
# 3548   1295                   Stafford Data Science Tutor Jobs
# 3549   1296                     Spring Data Science Tutor Jobs
#
#                        Salary Estimate  \
# 2149                                -1
# 2938  $34-$53 Per Hour(Glassdoor est.)
# 2939  $34-$53 Per Hour(Glassdoor est.)
# 2940  $34-$53 Per Hour(Glassdoor est.)
# 2941  $34-$53 Per Hour(Glassdoor est.)
# 2942  $34-$53 Per Hour(Glassdoor est.)
# 2943  $34-$53 Per Hour(Glassdoor est.)
# 2944  $34-$53 Per Hour(Glassdoor est.)
# 3548  $10-$26 Per Hour(Glassdoor est.)
# 3549  $10-$26 Per Hour(Glassdoor est.)
#
#                                         Job Description  Rating  \
# 2149  Job Description\nPosition Title: Configuration...     4.4
# 2938  As the Clinical Laboratory Scientist, you will...     3.8
# 2939  As a Sr. Data Analyst, you will work closely w...     2.8
# 2940  Job Description\nGalvanize is a dynamic learni...    -1.0
# 2941  Monterey Park Hospital, located in the San Gab...     3.0
# 2942  Responsibilities:* Responsible for building an...    -1.0
# 2943  LGC Labs is the trusted partner in laboratory ...     3.8
# 2944  Job Overview:\n\n\nCovance is looking for a Cl...     3.4
# 3548  #Stafford Data Science Tutor Jobs\n\nVarsity T...     4.2
# 3549  #Spring Data Science Tutor Jobs\n\nVarsity Tut...     4.2
#
#                                            Company Name            Location  \
# 2149                                    Protingent\n4.4            Kent, WA
# 2938                       UC Davis Medical Center\n3.8     Los Angeles, CA
# 2939  SAG-AFTRA Health Plan and SAG-Producers Pensio...         Burbank, CA
# 2940                                     Galvanize Inc.     Los Angeles, CA
# 2941                               AHMC Healthcare\n3.0   Monterey Park, CA
# 2942                                  BlackLine Systems  Woodland Hills, CA
# 2943                                LetsGetChecked\n3.8        Monrovia, CA
# 2944                                       Covance\n3.4     Los Angeles, CA
# 3548                                Varsity Tutors\n4.2        Stafford, TX
# 3549                                Varsity Tutors\n4.2          Spring, TX
#
#          Headquarters                     Size  Founded  \
# 2149     Bellevue, WA      51 to 200 employees     2001
# 2938   Sacramento, CA         10000+ employees       -1
# 2939      Burbank, CA                  Unknown       -1
# 2940   Harrisburg, NC      51 to 200 employees       -1
# 2941     Alhambra, CA  5001 to 10000 employees     1998
# 2942  Markham, Canada        1 to 50 employees       -1
# 2943     New York, NY      51 to 200 employees     2015
# 2944   Burlington, NC         10000+ employees     1996
# 3548  Saint Louis, MO     201 to 500 employees     2007
# 3549  Saint Louis, MO     201 to 500 employees     2007
#
#            Type of ownership                          Industry  \
# 2149       Company - Private            Staffing & Outsourcing
# 2938  Nonprofit Organization  Health Care Services & Hospitals
# 2939       Company - Private                                -1
# 2940       Company - Private                      Construction
# 2941       Company - Private  Health Care Services & Hospitals
# 2942                 Unknown                                -1
# 2943       Company - Private  Health Care Services & Hospitals
# 2944        Company - Public         Biotech & Pharmaceuticals
# 3548       Company - Private                          Internet
# 3549       Company - Private                          Internet
#
#                                   Sector                   Revenue  \
# 2149                   Business Services  $25 to $50 million (USD)
# 2938                         Health Care    $2 to $5 billion (USD)
# 2939                                  -1  Unknown / Non-Applicable
# 2940  Construction, Repair & Maintenance  Unknown / Non-Applicable
# 2941                         Health Care    $1 to $2 billion (USD)
# 2942                                  -1  Unknown / Non-Applicable
# 2943                         Health Care  Unknown / Non-Applicable
# 2944           Biotech & Pharmaceuticals  $10 to $25 million (USD)
# 3548              Information Technology  Unknown / Non-Applicable
# 3549              Information Technology  Unknown / Non-Applicable
#
#                           Competitors Easy Apply  Salary_min_grand  \
# 2149                               -1      False                -1
# 2938                               -1      False                -1
# 2939                               -1      False                -1
# 2940                               -1      False                -1
# 2941                               -1      False                -1
# 2942                               -1      False                -1
# 2943                               -1      False                -1
# 2944  PRA Health Sciences, PPD, IQVIA      False                -1
# 3548                               -1      False                -1
# 3549                               -1      False                -1
#
#       Salary_max_grand
# 2149                -1
# 2938                -1
# 2939                -1
# 2940                -1
# 2941                -1
# 2942                -1
# 2943                -1
# 2944                -1
# 3548                -1
# 3549                -1

# %% [markdown]
# There are so few and one cannot be sure that they would assign their employee 30hrs a week. (infact it's possible that the reason they chose this form of salary estimate was because they specifically intended not to assign 30 hours a week to their employee.) Thus I shall be dropping these rows.

# %%
# Quick check to make sure the correct rows are being deleted
mask = df['Salary_min_grand'] == -1
df.drop(df[mask].index).loc[2935: 2945]
# Out:
#       index                                          Job Title  \
# 2935    682                                   Sr Data Engineer
# 2936    683  Project Scientist - Department of Medicine - N...
# 2937    684                                      Data Engineer
# 2945    692                                     Data Scientist
#
#                    Salary Estimate  \
# 2935  $136K-$164K (Glassdoor est.)
# 2936  $136K-$164K (Glassdoor est.)
# 2937  $136K-$164K (Glassdoor est.)
# 2945    $46K-$80K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 2935  Job Description\nLoot Crate was founded in 201...     2.1
# 2936  As a Project Scientist, you may assist in prep...     3.9
# 2937  Company Overview:\nAge of Learning is a leadin...     3.3
# 2945  Ready to write the best chapter of your career...     3.8
#
#                  Company Name         Location     Headquarters  \
# 2935    The Loot Company\n2.1  Los Angeles, CA  Los Angeles, CA
# 2936        Cedars-Sinai\n3.9  Los Angeles, CA  Los Angeles, CA
# 2937     Age of Learning\n3.3     Glendale, CA     Glendale, CA
# 2945  XSELL Technologies\n3.8      Chicago, IL      Chicago, IL
#
#                        Size  Founded       Type of ownership  \
# 2935   201 to 500 employees     2012       Company - Private
# 2936       10000+ employees     1902  Nonprofit Organization
# 2937  501 to 1000 employees     2007       Company - Private
# 2945    51 to 200 employees     2014       Company - Private
#
#                                      Industry                  Sector  \
# 2935                      Other Retail Stores                  Retail
# 2936         Health Care Services & Hospitals             Health Care
# 2937                           K-12 Education               Education
# 2945  Enterprise Software & Network Solutions  Information Technology
#
#                          Revenue  \
# 2935    Unknown / Non-Applicable
# 2936      $2 to $5 billion (USD)
# 2937  $100 to $500 million (USD)
# 2945    Unknown / Non-Applicable
#
#                                           Competitors Easy Apply  \
# 2935                                               -1      False
# 2936  UCLA Health, City of Hope, Keck Medicine of USC      False
# 2937                             Top Hat, Flocabulary      False
# 2945                                               -1      False
#
#       Salary_min_grand  Salary_max_grand
# 2935               136               164
# 2936               136               164
# 2937               136               164
# 2945                46                80

# %%
mask = df['Salary_min_grand'] == -1
df.drop(df[mask].index, inplace = True)

# %%
df['Competitors'].replace('-1', 'Unknown', inplace = True)

# %%
for col in df.columns:
    mask = (df[col] == "-1") | (df[col] == -1)
    print(df[mask].shape[0], col)
# Out:
# 0 index
# 0 Job Title
# 0 Salary Estimate
# 0 Job Description
# 676 Rating
# 0 Company Name
# 0 Location
# 411 Headquarters
# 391 Size
# 1629 Founded
# 391 Type of ownership
# 895 Industry
# 895 Sector
# 0 Revenue
# 4473 Competitors
# 0 Easy Apply
# 0 Salary_min_grand
# 0 Salary_max_grand
# 0 temp
# 0 Company_name

# %%
mask = (df['Type of ownership'] == "-1")# | (df[col] == -1)
df[mask].head()
# Out:
#      index               Job Title             Salary Estimate  \
# 34      34    Data Analyst (Games)  $46K-$87K (Glassdoor est.)
# 55      55  Data Reporting Analyst  $46K-$87K (Glassdoor est.)
# 68      68    Data Science Analyst  $51K-$88K (Glassdoor est.)
# 90      90            Data Analyst  $51K-$87K (Glassdoor est.)
# 109    109            Data Analyst  $51K-$87K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 34   Carry1st is the leading mobile game publisher ...    -1.0
# 55   OverviewThe Data Analyst is a new position in ...    -1.0
# 68   Job Details\n\nLevel\n\nExperienced\n\nJob Loc...    -1.0
# 90   NYU Grossman School of Medicine is one of the ...    -1.0
# 109  Data Analyst\n\nJersey City, NJ\n\n12+ months ...    -1.0
#
#                                           Company Name         Location  \
# 34                                            Carry1st     New York, NY
# 55                                      NADAP NYS INC.     New York, NY
# 68   Greater New York Mutual Insurance Companies (GNY)     New York, NY
# 90                          NYU Langone Medical Center     New York, NY
# 109                               Vertex Intel Systems  Jersey City, NJ
#
#     Headquarters Size  Founded Type of ownership Industry Sector  \
# 34            -1   -1       -1                -1       -1     -1
# 55            -1   -1       -1                -1       -1     -1
# 68            -1   -1       -1                -1       -1     -1
# 90            -1   -1       -1                -1       -1     -1
# 109           -1   -1       -1                -1       -1     -1
#
#                       Revenue Competitors Easy Apply  Salary_min_grand  \
# 34   Unknown / Non-Applicable          -1      False                46
# 55   Unknown / Non-Applicable          -1      False                46
# 68   Unknown / Non-Applicable          -1      False                51
# 90   Unknown / Non-Applicable          -1      False                51
# 109  Unknown / Non-Applicable          -1      False                51
#
#      Salary_max_grand           temp  \
# 34                 87  <class 'str'>
# 55                 87  <class 'str'>
# 68                 88  <class 'str'>
# 90                 87  <class 'str'>
# 109                87  <class 'str'>
#
#                                           Company_name
# 34                                            Carry1st
# 55                                      NADAP NYS INC.
# 68   Greater New York Mutual Insurance Companies (GNY)
# 90                          NYU Langone Medical Center
# 109                               Vertex Intel Systems

# %%
# These seem to have a bunch of nulls so I'm going to drop these.
df.drop(df[mask].index, inplace = True)

# %%
# Still leaves us with over 5,000 datapoints!
df.shape
# Out:
# (5748, 20)

# %%
mask = (df['Headquarters'] == "-1")# | (df[col] == -1)
df.drop(df[mask].index, inplace = True)#.head()

# %%
mask = (df['Industry'] == "-1")# | (df[col] == -1)
df.drop(df[mask].index, inplace = True)#.head()

# %%
mask = (df['Rating'] == -1)# | (df[col] == -1)
df.drop(df[mask].index, inplace = True)#.head()

# %%
df.shape
# Out:
# (5134, 20)

# %% [markdown]
# I still have over 5,000 data points, so dropping over 1,000 is fine by me.

# %%
for col in df.columns:
    mask = (df[col] == "-1") | (df[col] == -1)
    print(df[mask].shape[0], col)
# Out:
# 0 index
# 0 Job Title
# 0 Salary Estimate
# 0 Job Description
# 0 Rating
# 0 Company Name
# 0 Location
# 0 Headquarters
# 0 Size
# 722 Founded
# 0 Type of ownership
# 0 Industry
# 0 Sector
# 0 Revenue
# 3487 Competitors
# 0 Easy Apply
# 0 Salary_min_grand
# 0 Salary_max_grand
# 0 temp
# 0 Company_name
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %% [markdown]
# These are acceptable Nulls to have

# %% [markdown]
# ### Cleaning values to read better

# %%
#mask = type(df['Company Name']) == type(float)
#df[mask]
df['temp'] = df['Company Name'].map(lambda x: type(x))
mask = df['temp'] == float
df[mask]
# Out:
#       index     Job Title             Salary Estimate  \
# 1860   1860  Data Analyst  $53K-$99K (Glassdoor est.)
#
#                                         Job Description  Rating Company Name  \
# 1860  Kindred at Home, part of the Kindred at Home f...    -1.0          NaN
#
#              Location Headquarters Size  Founded Type of ownership Industry  \
# 1860  Mooresville, NC           -1   -1       -1                -1       -1
#
#      Sector                   Revenue Competitors Easy Apply  \
# 1860     -1  Unknown / Non-Applicable          -1      False
#
#       Salary_min_grand  Salary_max_grand             temp
# 1860                53                99  <class 'float'>

# %%
 df.drop(1860, inplace = True)#.loc[1855:1865]

# %%
df['Company Name'].map(lambda x: x[:-4])
# Out:
# 0                Vera Institute of Justice
# 1       Visiting Nurse Service of New York
# 2                              Squarespace
# 3                                 Celerity
# 4                                  FanDuel
#                        ...
# 6157                  Tachyon Technologies
# 6158      Staffigo Technical Services, LLC
# 6159                        PDS Tech, Inc.
# 6160            Data Resource Technologies
# 6161                                   UCB
# Name: Company Name, Length: 6139, dtype: object

# %%
df['Company Name'].map(lambda x: x[-4:]).value_counts().head(30)
# Out:
# \n3.9    442
# \n3.7    421
# \n4.1    391
# \n3.6    386
# \n3.8    365
# \n4.0    327
# \n3.5    300
# \n5.0    291
# \n3.4    285
# \n3.3    262
# \n3.2    227
# \n4.2    197
# \n3.1    181
# \n4.3    174
# \n4.5    155
# \n4.4    121
# \n3.0    121
# \n4.6    120
# \n2.9    103
# \n2.8    100
# \n4.7     82
# \n4.8     71
# \n2.5     65
# Inc.      64
# \n4.9     62
# \n2.7     54
#  LLC      52
# \n2.6     41
#  Inc      31
# \n2.4     30
# Name: Company Name, dtype: int64

# %%
mask = df['Rating'] == -1
df[mask]['Company Name'].map(lambda x: x[-4:]).value_counts()#.head(50)
# Out:
# Inc.    64
#  LLC    52
#  Inc    31
# ions    18
# fing    14
#         ..
# ific     1
# stem     1
# URCH     1
# n TX     1
# Corp     1
# Name: Company Name, Length: 243, dtype: int64

# %%
mask = df['Rating'] != -1
df[mask]['Company Name'].map(lambda x: x[-4:]).value_counts().head(10)
# Out:
# \n3.9    442
# \n3.7    421
# \n4.1    391
# \n3.6    386
# \n3.8    365
# \n4.0    327
# \n3.5    300
# \n5.0    291
# \n3.4    285
# \n3.3    262
# Name: Company Name, dtype: int64

# %%
def fun_map(x):
    if x[-4:-3] == "\n":
        x = x[:-4]
    return x
df['Company Name'].map(lambda x: fun_map(x)).value_counts()

# %%
def fun_map(x):
    if x[-4:-3] == "\n":
        x = x[:-4]
    return x
#df['Company Name'] = 
df['Company_name'] = df['Company Name'].map(lambda x: fun_map(x))

# %%
df['Salary_range'] = df['Salary_max_grand'] - df['Salary_min_grand']

# %%
df['Size'] = df['Size'].map(lambda x: x.strip(' employees'))

# %%
df['Revenue'] = df['Revenue'].map(lambda x: x.strip(' (USD)'
                            ).replace('million', 'M'
                            ).replace('billion', 'B'
                            ).replace('nknown','Unknown'))#.value_counts()

# %%
df['Revenue'].value_counts()
# Out:
# Unknown / Non-Applicable    1316
# $10+ B                       773
# $100 to $500 M               551
# $50 to $100 M                403
# $2 to $5 B                   339
# $10 to $25 M                 308
# $1 to $2 B                   266
# $25 to $50 M                 243
# $1 to $5 M                   230
# $500 M to $1 B               193
# $5 to $10 B                  188
# Less than $1 M               171
# $5 to $10 M                  153
# Name: Revenue, dtype: int64

# %%
df = df.reset_index().drop(['index', 'Company Name', 'Salary Estimate', 'temp', 'level_0'], axis = 1)#.tail()

# %%
df.to_csv('./Job_data/data_cleaned_9_13_20.csv', index = False)
